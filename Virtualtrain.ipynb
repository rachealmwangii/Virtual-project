# %%
# !pip install pandas numpy scikit-learn seaborn tabulate

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# %%
df =pd.read_csv('/content/drive/MyDrive/Classroom/Untitled folder/train.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.size
# Out:
# 7982

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
from os import name
column_names= df.columns.tolist()
column_names_table= [[i+1, name] for i, name in enumerate(column_names)]
print(tabulate(column_names_table, headers= ["index", "column name"]))
# Out:
#   index  column name
# -------  -----------------
#       1  Loan_ID
#       2  Gender
#       3  Married
#       4  Dependents
#       5  Education
#       6  Self_Employed
#       7  ApplicantIncome
#       8  CoapplicantIncome
#       9  LoanAmount
#      10  Loan_Amount_Term
#      11  Credit_History
#      12  Property_Area
#      13  Loan_Status

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df =df.apply(pd.to_numeric, errors= 'coerce')
df
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0        NaN     NaN      NaN         0.0        NaN            NaN
# 1        NaN     NaN      NaN         1.0        NaN            NaN
# 2        NaN     NaN      NaN         0.0        NaN            NaN
# 3        NaN     NaN      NaN         0.0        NaN            NaN
# 4        NaN     NaN      NaN         0.0        NaN            NaN
# ..       ...     ...      ...         ...        ...            ...
# 609      NaN     NaN      NaN         0.0        NaN            NaN
# 610      NaN     NaN      NaN         NaN        NaN            NaN
# 611      NaN     NaN      NaN         1.0        NaN            NaN
# 612      NaN     NaN      NaN         2.0        NaN            NaN
# 613      NaN     NaN      NaN         0.0        NaN            NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.mean()
# Out:
# Loan_ID                      NaN
# Gender                       NaN
# Married                      NaN
# Dependents              0.554745
# Education                    NaN
# Self_Employed                NaN
# ApplicantIncome      5403.459283
# CoapplicantIncome    1621.245798
# LoanAmount            146.412162
# Loan_Amount_Term      342.000000
# Credit_History          0.842199
# Property_Area                NaN
# Loan_Status                  NaN
# dtype: float64

# %%
df.fillna(df.mean(), inplace= True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              614
# Gender               614
# Married              614
# Dependents             0
# Education            614
# Self_Employed        614
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term       0
# Credit_History         0
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
num_col= ['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
num_col
# Out:
# ['Dependents',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
plt.figure(figsize= (10, 6))
for i, columns in enumerate(df[num_col]):
  plt.subplot(3, 3, i+1)
  sns.histplot(df[num_col], bins='auto', kde=True)
  plt.title('Distribution of {col}')
  plt.xlabel({'col'})
  plt.ylabel('Frequency')
  plt.tight_layout()
  plt.show()

# %%
le= LabelEncoder()
df['ApplicantIncome']= le.fit_transform(df['ApplicantIncome'])
X= df.drop('ApplicantIncome', axis=1)
Y=df['ApplicantIncome']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2, random_state= 42)
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1137: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1142: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1162: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
sns.pairplot(df, hue='LoanAmount')
plt.show()

# %%
df[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']].corr()
# Out:
#                    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Dependents           1.000000         0.095605           0.000232    0.113444
# ApplicantIncome      0.095605         1.000000          -0.205261    0.525324
# CoapplicantIncome    0.000232        -0.205261           1.000000    0.212427
# LoanAmount           0.113444         0.525324           0.212427    1.000000
# Loan_Amount_Term    -0.063726        -0.026696          -0.059675    0.056089
# Credit_History      -0.007399         0.041996          -0.001665   -0.005087
#
#                    Loan_Amount_Term  Credit_History
# Dependents                -0.063726       -0.007399
# ApplicantIncome           -0.026696        0.041996
# CoapplicantIncome         -0.059675       -0.001665
# LoanAmount                 0.056089       -0.005087
# Loan_Amount_Term           1.000000        0.001395
# Credit_History             0.001395        1.000000

# %%
sns.heatmap(df[['Credit_History', 'LoanAmount', 'Loan_Amount_Term', 'ApplicantIncome']].corr(), vmax=.3, center=0, cmap='coolwarm', square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >
